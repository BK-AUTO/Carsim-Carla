# %% [markdown]
# # Run Simulation and Capture Output
# This notebook executes the `main.py` script and displays the exact terminal output.

# %%
# Run the main script to see terminal output
# %run main.py
# Out:
# 🚗 CHẠY MÔ PHỎNG VỚI THAM SỐ TÙY CHỈNH
# Khối lượng xe: 2530 kg
# Hệ số cản gió: 0.23
# Hệ số cản lăn: 0.016
# Thời gian mô phỏng: 100.0 giây
# ------------------------------------------------------------
# Integrated Vehicle Simulation - All Outputs (with Front & Rear Tire Models + Braking + Battery)
# ...
# Time   DesVel   ActVel   Pedal    Accel    Dist     Fzf      Fxf      Fzr      Fxr      SlipF    SlipR    BrMode     RegenT     MechT      SOC      BatV     BatI     BatP(W)
# (s)    (km/h)   (km/h)   pos      (m/s²)   (m)      (N)      (N)      (N)      (N)                                   (Nm)       (Nm)       (%)      (V)      (A)      (W)
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...
